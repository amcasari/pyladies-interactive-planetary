# %% [markdown]
# #### Set up the notebook bits

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cd "/Users/amcasari/repos/pyladies-interactive-planetary/"
# Out:
# /Users/amcasari/repos/pyladies-interactive-planetary

# %% [markdown]
# ## Import your bookmarks file

# %%
bookmarks_html = open('data/bookmarks_2_18_16.html')
bookmarks_html
# Out:
# <open file 'data/bookmarks_2_18_16.html', mode 'r' at 0x106ccbae0>

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(bookmarks_html, 'html.parser')

print(soup.prettify())
# Out:
# <!DOCTYPE NETSCAPE-Bookmark-file-1>
# <!-- This is an automatically generated file.
#      It will be read and overwritten.
#      DO NOT EDIT! -->
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type">
#  <title>
#   Bookmarks
#  </title>
#  <h1>
#   Bookmarks
#  </h1>
#  <dl>
#   <p>
#    <dt>
#     <h3 add_date="1441769855" last_modified="1455825536" personal_toolbar_folder="true">
#      Bookmarks Bar
#     </h3>
#     <dl>
#      <p>
#       <dt>
#        <h3 add_date="1455825216" last_modified="1455825362">
#         rad
#        </h3>
#        <dl>
#         <p>
#          <dt>
#           <h3 add_date="1442806965" last_modified="1454189482">
#            style
#           </h3>
#           <dl>
#            <p>
#             <dt>
#              <a add_date="1442806953" href="http://www.girlofacertainage.com/" icon="data:image/png;base64,...">
#               Girls of a Certain Age - You know who you are.
#              </a>
#              <dt>
# ...

# %% [markdown]
# ## What Data Could Be Useful?

# %%
# links i decided to keep
my_links = []
for link in soup.find_all('a'):
    my_links.append(link.get('href'))

# %%
# how I organize my links
my_dirs = soup.find_all('h3')

# %%
# what I call my links
my_names = soup.get_text()

# %% [markdown]
# ## Shape the Data for Exploratory Vis

# %%
# regex....painful but useful

# links: count http, https
# links:

# %% [markdown]
# ## Exploratory Interactive Vis

# %% [markdown]
# ### credit where credit is due: refs
#
# - [Beautiful Soup documentation](http://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - []()
# - []()
# - []()
# - []()
# - []()
